# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
from time_series_helper import lineplot

plt.style.use('seaborn-v0_8-whitegrid')

# %% [markdown]
# ## Input new filepath here

# %%
data = 'daily-max-temperatures.csv'

# %% [markdown]
# ## Load and Plot the Data

# %%
filepath = 'Datasets-master/'+data
df = pd.read_csv(filepath, header=0, index_col=0, parse_dates=True)
df.index = df.index.rename('Date')
df.head()
# Out:
#             Temperature
# Date
# 1981-01-01         38.1
# 1981-01-02         32.4
# 1981-01-03         34.5
# 1981-01-04         20.7
# 1981-01-05         21.5

# %%
lineplot(df, df.columns[0])
